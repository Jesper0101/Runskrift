# %%
import pandas as pd

# %%
path_file = r'C:\Users\charmingstar\Downloads\rundata_clean_utcoordinate.csv'
df = pd.read_csv(path_file, encoding='utf-8-sig')

# %%
print(df.head())
# Out:
#      Signum             Plats         Socken          Härad      Kommun  \
# 0   Öl 1 $            Karlevi    Vickleby sn  Algutsrums hd  Mörbylånga
# 1  Öl 2 †$   Algutsrums kyrka  Algutsrums sn  Algutsrums hd  Mörbylånga
# 2  Öl 3 †$        Resmo kyrka       Resmo sn  Algutsrums hd  Mörbylånga
# 3   Öl 4 $        Resmo kyrka       Resmo sn  Algutsrums hd  Mörbylånga
# 4   Öl 5 †              Bårby  Mörbylånga sn  Algutsrums hd  Mörbylånga
#
#                         Placering  Koordinater Runtyper Korsform  \
# 0                             NaN  6275755.154      NaN      NaN
# 1                             NaN  6283750.154      NaN      NaN
# 2                             NaN  6268390.154      NaN      NaN
# 3  Kalmar läns museum (KLM 24962)  6268390.154      NaN      NaN
# 4                             NaN  6264000.154      NaN      NaN
#
#   Period/Datering Stilgruppering Ristare Materialtyp        Material  \
# ...

# %%
df['Longtitude_orig'] = df['Koordinater'].str.split(';').str[1].str.strip()
df['Longtitude_orig'] = df['Longtitude_orig'].str.replace(r'[()]', '', regex=True)

# %%
df['Kommun'] = df['Kommun'].str.split(' ').str[0]
df['Kommun'] = df['Kommun'].str.replace(',', '')
df['Kommun'] = df['Kommun'].str.replace('?', '')
df['Kommun'] = df['Kommun'].fillna('')
# Out:
# C:\Users\CHARMI~1\AppData\Local\Temp/ipykernel_10380/3377867820.py:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['Kommun'] = df['Kommun'].str.replace('?', '')

# %%
unique_kummum_values = df['Kommun'].unique()

# %%
unique_kummum_df = pd.DataFrame(unique_kummum_values, columns=['kummun'])

# %%
output_file = r'C:\Users\charmingstar\Downloads\unique_kummum_values.csv'
unique_kummum_df.to_csv(output_file, index=False)

# %%
kommun_to_latitude_longitude = {
    'Mörbylånga': (56.5279, 16.3835),
    'Borgholm': (56.8780, 16.6561),
    'Motala': (58.5371, 15.0407),
    'Vadstena': (58.4470, 14.8912),
    'Linköping': (58.4108, 15.6214),
    'Norrköping': (58.5881, 16.1904),
    'Mjölby': (58.3220, 15.1300),
    'Boxholm': (58.1927, 15.0536),
    'Söderköping': (58.4800, 16.3213),
    'Valdemarsvik': (58.2034, 16.6001),
    'Kinda': (58.1152, 15.5810),
    'Ödeshög': (58.2286, 14.6589),
    'Ydre': (57.7854, 15.3057),
    'Gnesta': (59.0497, 17.3117),
    'Södertälje': (59.1955, 17.6253),
    'Trosa': (58.8956, 17.5477),
    'Nyköping': (58.7530, 17.0079),
    'Flen': (59.0591, 16.5881),
    'Katrineholm': (59.0000, 16.2079),
    'Vingåker': (59.0466, 15.8667),
    'Eskilstuna': (59.3666, 16.5064),
    'Strängnäs': (59.3771, 17.0312),
    'Nynäshamn': (58.9050, 17.9470),
    'Haninge': (59.1675, 18.1437),
    'Stockholm': (59.3293, 18.0686),
    'Botkyrka': (59.2015, 17.8330),
    'Huddinge': (59.2370, 17.9810),
    'Salem': (59.2005, 17.7189),
    'Kungsör': (59.4267, 16.0999),
    'Nykvarn': (59.1953, 17.4340),
    'Tyresö': (59.2370, 18.2940),
    'Alvesta': (56.8990, 14.5547),
    'Växjö': (56.8790, 14.8059),
    'Tingsryd': (56.5284, 14.9775),
    'Uppvidinge': (57.0364, 15.2259),
    'Ljungby': (56.8323, 13.9407),
    'Älmhult': (56.5531, 14.1366),
    'Värnamo': (57.1860, 14.0403),
    'Gislaved': (57.3047, 13.5415),
    'Hylte': (56.9957, 13.2362),
    'Vaggeryd': (57.4970, 14.1404),
    'Nässjö': (57.6536, 14.6967),
    'Vetlanda': (57.4265, 15.0785),
    'Sävsjö': (57.4000, 14.6658),
    'Jönköping': (57.7826, 14.1628),
    'Aneby': (57.8372, 14.8099),
    'Tranås': (58.0371, 14.9797),
    'Eksjö': (57.6640, 14.9716),
    'Västervik': (57.7584, 16.4826),
    'Hultsfred': (57.4921, 15.8432),
    'Högsby': (57.1664, 16.0175),
    'Kalmar': (56.6634, 16.3566),
    'Markaryd': (56.4613, 13.5912),
    'Skövde': (58.3911, 13.8445),
    'Mariestad': (58.7094, 13.8232),
    'Töreboda': (58.7047, 14.1280),
    'Lidköping': (58.5000, 13.1577),
    'Götene': (58.5275, 13.4940),
    'Vara': (58.2555, 12.9545),
    'Skara': (58.3857, 13.4384),
    'Falköping': (58.1734, 13.5506),
    'Grästorp': (58.3250, 12.6816),
    'Vänersborg': (58.3805, 12.3235),
    'Essunga': (58.2000, 12.7167),
    'Tidaholm': (58.1810, 13.9642),
    'Trollhättan': (58.2835, 12.2886),
    'Herrljunga': (58.0821, 13.0224),
    'Vårgårda': (58.0331, 12.8035),
    'Ulricehamn': (57.7912, 13.4147),
    'Borås': (57.7210, 12.9400),
    'Mark': (57.4504, 12.5697),
    'Tranemo': (57.4861, 13.3500),
    'Svenljunga': (57.4960, 12.7220),
    'Göteborg': (57.7089, 11.9746),
    'Tibro': (58.4214, 14.1589),
    'Lilla Edet': (58.1275, 12.1276),
    'Alingsås': (57.9280, 12.5336),
    'Bollebygd': (57.6681, 12.6001),
    'Falkenberg': (56.9056, 12.4916),
    'Ekerö': (59.2975, 17.8142),
    'Sundbyberg': (59.3610, 17.9700),
    'Järfälla': (59.4140, 17.8354),
    'Sollentuna': (59.4283, 17.9505),
    'Upplands-Väsby': (59.5184, 17.9113),
    'Solna': (59.3630, 17.9960),
    'Danderyd': (59.3990, 18.0360),
    'Täby': (59.4439, 18.0687),
    'Österåker': (59.4828, 18.2955),
    'Vaxholm': (59.4035, 18.3536),
    'Lidingö': (59.3664, 18.1304),
    'Värmdö': (59.3253, 18.4780),
    'Norrtälje': (59.7590, 18.7036),
    'Vallentuna': (59.5342, 18.0771),
    'Sigtuna': (59.6165, 17.7235),
    'Knivsta': (59.7250, 17.7931),
    'Uppsala': (59.8586, 17.6389),
    'Östhammar': (60.2640, 18.3743),
    'Upplands-Bro': (59.5158, 17.6622),
    'Håbo': (59.5630, 17.5430),
    'Enköping': (59.6362, 17.0792),
    'Tierp': (60.3434, 17.5173),
    'Älvkarleby': (60.5667, 17.4167),
    'Heby': (59.9404, 16.8622),
    'Nacka': (59.3080, 18.1620),
    'Västerås': (59.6162, 16.5528),
    'Sala': (59.9238, 16.6062),
    'Hallsberg': (59.0667, 15.1167),
    'Lekeberg': (59.1840, 14.8723),
    'Kumla': (59.1276, 15.1451),
    'Askersund': (58.8789, 14.9039),
    'Örebro': (59.2753, 15.2134),
    'Arboga': (59.3954, 15.8385),
    'Kristinehamn': (59.3095, 14.1082),
    'Karlstad': (59.3793, 13.5036),
    'Hammarö': (59.2834, 13.4977),
    'Forshaga': (59.5276, 13.4818),
    'Säffle': (59.1322, 12.9289),
    'Arvika': (59.6569, 12.5873),
    'Sandviken': (60.6161, 16.7759),
    'Gävle': (60.6749, 17.1413),
    'Hofors': (60.5639, 16.2831),
    'Ockelbo': (60.8873, 16.7161),
    'Bollnäs': (61.3507, 16.3944),
    'Söderhamn': (61.3039, 17.0595),
    'Ljusdal': (61.8285, 16.0921),
    'Hudiksvall': (61.7271, 17.1047),
    'Nordanstig': (62.0855, 17.1047),
    'Sundsvall': (62.3908, 17.3069),
    'Timrå': (62.4864, 17.3297),
    'Kramfors': (62.9326, 17.7892),
    'Leksand': (60.7326, 14.9909),
    'Avesta': (60.1477, 16.1674),
    'Mora': (61.0097, 14.5378),
    'Älvdalen': (61.2224, 13.7816),
    'Borlänge': (60.4877, 15.4370),
    'Härjedalen': (62.4157, 13.9364),
    'Berg': (62.5821, 14.4298),
    'Östersund': (63.1792, 14.6357),
    'Strömsund': (63.8507, 15.5584),
    'Åsele': (64.1556, 17.3496),
    'Lysekil': (58.2739, 11.4403),
    'Kungälv': (57.8710, 11.9753),
    'Stenungsund': (58.0681, 11.8199),
    'Uddevalla': (58.3498, 11.9382),
    'Strömstad': (58.9389, 11.1710),
    'Sotenäs': (58.3645, 11.2794),
    'Munkedal': (58.4596, 11.6777),
    'Tanum': (58.7220, 11.2813),
    'Tjörn': (58.0206, 11.5629),
    'Orust': (58.1530, 11.6822),
    'Gotland': (57.5310, 18.2872),
    'Trelleborg': (55.3764, 13.1569),
    'Svedala': (55.5075, 13.2369),
    'Malmö': (55.6050, 13.0038),
    'Staffanstorp': (55.6417, 13.2046),
    'Skurup': (55.4785, 13.4982),
    'Ystad': (55.4296, 13.8205),
    'Lund': (55.7047, 13.1910),
    'Lomma': (55.6721, 13.0664),
    'Eslöv': (55.8390, 13.3031),
    'Kävlinge': (55.7900, 13.1082),
    'Höör': (55.9403, 13.5411),
    'Landskrona': (55.8708, 12.8295),
    'Helsingborg': (56.0465, 12.6945),
    'Simrishamn': (55.5562, 14.3507),
    'Tomelilla': (55.5452, 13.9499),
    'Kristianstad': (56.0308, 14.1526),
    'Hässleholm': (56.1590, 13.7668),
    'Halmstad': (56.6745, 12.8574),
    'Sölvesborg': (56.0496, 14.5790),
    'Ronneby': (56.2105, 15.2760),
    'Karlshamn': (56.1710, 14.8615),
    'Karlskrona': (56.1612, 15.5866),
    'Selk': (54.5031, 9.5717),
    'Busdorf': (54.5070, 9.5528),
    'Schleswig': (54.5205, 9.5669),
    'Süderbrarup': (54.6542, 9.7807),
    'Norderbrarup': (54.6647, 9.7346),
    'Aabenraa': (55.0447, 9.4175),
    'Tønder': (54.9355, 8.8663),
    'Sønderborg': (54.9130, 9.7925),
    'Haderslev': (55.2494, 9.4872),
    'Kolding': (55.4919, 9.4723),
    'Esbjerg': (55.4707, 8.4510),
    'Vejen': (55.4770, 9.1371),
    'Skive': (56.5665, 9.0263),
    'Varde': (55.6214, 8.4864),
    'Vejle': (55.7110, 9.5369),
    'Fredericia': (55.5657, 9.7490),
    'Billund': (55.7308, 9.1153),
    'Ringkøbing-Skjern': (56.0904, 8.2746),
    'Ikast-Brande': (56.1396, 9.1579),
    'Holstebro': (56.3601, 8.6164),
    'Odder': (55.9734, 10.1532),
    'Horsens': (55.8608, 9.8504),
    'Skanderborg': (56.0395, 9.9317),
    'Aarhus': (56.1629, 10.2039),
    'Favrskov': (56.3370, 9.8500),
    'Silkeborg': (56.1697, 9.5445),
    'Viborg': (56.4510, 9.4046),
    'Randers': (56.4608, 10.0367),
    'Syddjurs': (56.3095, 10.6745),
    'Norddjurs': (56.4514, 10.7609),
    'Mariagerfjord': (56.6562, 9.9912),
    'Rebild': (56.8022, 9.8077),
    'Vesthimmerland': (56.7581, 9.3542),
    'Aalborg': (57.0488, 9.9217),
    'Struer': (56.4912, 8.5837),
    'Thisted': (56.9550, 8.6944),
    'Morsø': (56.7910, 8.6986),
    'Jammerbugt': (57.0825, 9.5536),
    'Brønderslev': (57.2700, 9.9501),
    'Hjørring': (57.4624, 9.9825),
    'Langeland': (54.8495, 10.7117),
    'Faaborg-Midtfyn': (55.0996, 10.2393),
    'Svendborg': (55.0599, 10.6061),
    'Nyborg': (55.3126, 10.7920),
    'Tjøme': (59.1160, 10.4016),
    'Assens': (55.2700, 9.8980),
    'Odense': (55.4038, 10.4024),
    'Kerteminde': (55.4479, 10.6675),
    'Nordfyn': (55.5147, 10.2997),
    'Lolland': (54.7735, 11.3727),
    'Guldborgsund': (54.7701, 11.8742),
    'Vordingborg': (55.0098, 11.9102),
    'Næstved': (55.2299, 11.7609),
    'Faxe': (55.2483, 12.1224),
    'Stevn': (55.3096, 12.3899),
    'Slagelse': (55.4040, 11.3526),
    'Sorø': (55.4321, 11.5554),
    'Gørlev': (55.4710, 11.2882),
    'Holbæk': (55.7162, 11.7142),
    'Odsherred': (55.9299, 11.6695),
    'Kalundborg': (55.6828, 11.0887),
    'Roskilde': (55.6415, 12.0803),
    'Greve': (55.5837, 12.2885),
    'Høje-Taastrup': (55.6461, 12.3090),
    'Glostrup': (55.6664, 12.3961),
    'Egedal': (55.7726, 12.1901),
    'Frederiksberg': (55.6797, 12.5337),
    'Herlev': (55.7239, 12.4407),
    'Gribskov': (56.0891, 12.2997),
    'Bornholm': (55.1358, 14.9376),
    'Hillerød': (55.9294, 12.3007),
    'Sjöbo': (55.6335, 13.7052),
    'Frederikssund': (55.8380, 12.0737),
    'Køge': (55.4580, 12.1821),
    'Kungsbacka': (57.4871, 12.0767),
    'Eckernförde': (54.4736, 9.8377),
    'Höganäs': (56.1999, 12.5609),
    'Geltorf': (54.5110, 9.5116),
    'Allerød': (55.8665, 12.3459),
    'Furesø': (55.7873, 12.3621),
    'Ballerup': (55.7293, 12.3577),
    'Hürup': (54.7272, 9.6026),
    'Solrød': (55.5337, 12.2167),
    'Lejre': (55.6017, 11.9702),
    'Ringsted': (55.4423, 11.7917),
    'København': (55.6761, 12.5683),
    'Halsnæs': (55.9657, 11.9247),
    'Lyngby-Tårbæk': (55.7707, 12.5038),
    'Askim': (59.5839, 11.1624),
    'Rakkestad': (59.4261, 11.3479),
    'Eidsberg': (59.5164, 11.3003),
    'Sarpsborg': (59.2841, 11.1096),
    'Hvaler': (59.0309, 11.0184),
    'Fredrikstad': (59.2143, 10.9390),
    'Oslo': (59.9139, 10.7522),
    'Aurskog-Høland': (59.8835, 11.5684),
    'Sørum': (60.0515, 11.2630),
    'Nittedal': (60.0375, 10.8597),
    'Ullensaker': (60.1412, 11.1746),
    'Nannestad': (60.2515, 11.0327),
    'Ringsaker': (60.8820, 10.8959),
    'Stange': (60.7181, 11.2023),
    'Lesja': (62.1207, 8.8594),
    'Lom': (61.8360, 8.5686),
    'Vågå': (61.8789, 9.0950),
    'Nord-Fron': (61.6146, 9.6887),
    'Ringebu': (61.5301, 10.1374),
    'Gausdal': (61.2652, 10.1447),
    'Lillehammer': (61.1153, 10.4662),
    'Østre': (60.7952, 10.7197),
    'Sunndal': (62.6730, 8.5633),
    'Gran': (60.3515, 10.5619),
    'Sør-Aurdal': (60.6919, 9.5516),
    'Nord-Aurdal': (60.9880, 9.2909),
    'Vestre': (60.8962, 9.0950),
    'Øystre': (61.2501, 8.8153),
    'Vang': (61.1152, 8.3987),
    'Hurum': (59.6163, 10.5034),
    'Hole': (60.0302, 10.2788),
    'Ringerike': (60.1652, 10.2565),
    'Flå': (60.4244, 9.4690),
    'Ål': (60.6282, 8.5646),
    'Sigdal': (60.0417, 9.6062),
    'Øvre': (60.1957, 9.5641),
    'Lier': (59.7831, 10.2614),
    'Rollag': (60.0264, 9.3004),
    'Nore': (60.2836, 8.8587),
    'Sande': (59.5841, 10.2115),
    'Horten': (59.4173, 10.4834),
    'Andebu': (59.3499, 10.1833),
    'Tønsberg': (59.2675, 10.4076),
    'Sandefjord': (59.1312, 10.2166),
    'Larvik': (59.0535, 10.0351),
    'Nome': (59.2694, 9.2563),
    'Skien': (59.2096, 9.6089),
    'Bø': (59.4092, 9.0673),
    'Notodden': (59.5612, 9.2581),
    'Tinn': (59.8635, 8.8404),
    'Hjartdal': (59.5883, 8.6593),
    'Seljord': (59.4884, 8.6340),
    'Fyresdal': (59.1841, 8.0977),
    'Tokke': (59.4597, 8.0227),
    'Vinje': (59.5667, 7.8256),
    'Åmli': (58.7616, 8.4854),
    'Froland': (58.5705, 8.5997),
    'Grimstad': (58.3406, 8.5943),
    'Evje': (58.5855, 7.7741),
    'Bygland': (58.8422, 7.7973),
    'Valle': (59.2130, 7.5333),
    'Bykle': (59.3515, 7.3606),
    'Kristiansand': (58.1467, 7.9956),
    'Søgne': (58.0966, 7.8099),
    'Farsund': (58.0956, 6.8039),
    'Flekkefjord': (58.2973, 6.6614),
    'Sirdal': (58.8503, 6.8022),
    'Sokndal': (58.3383, 6.2936),
    'Eigersund': (58.4563, 6.0042),
    'Hå': (58.6177, 5.6452),
    'Klepp': (58.7697, 5.6425),
    'Sandnes': (58.8503, 5.7352),
    'Sola': (58.8886, 5.6500),
    'Stavanger': (58.9690, 5.7331),
    'Randaberg': (59.0097, 5.6194),
    'Hjelmeland': (59.2289, 6.1596),
    'Finnøy': (59.1705, 5.9193),
    'Rennesøy': (59.1264, 5.6867),
    'Karmøy': (59.2765, 5.2972),
    'Vindafjord': (59.5622, 5.7482),
    'Etne': (59.6607, 5.9314),
    'Kvam': (60.2491, 6.1295),
    'Odda': (60.0680, 6.5467),
    'Ullensvang': (60.3143, 6.6518),
    'Granvin': (60.5260, 6.7183),
    'Voss': (60.6296, 6.4191),
    'Os': (60.1886, 5.4591),
    'Bergen': (60.3913, 5.3221),
    'Osterøy': (60.4744, 5.5521),
    'Radøy': (60.7112, 5.0043),
    'Luster': (61.4070, 7.2860),
    'Årdal': (61.3144, 7.8060),
    'Lærdal': (61.1004, 7.4763),
    'Sogndal': (61.2291, 7.1018),
    'Vik': (61.0870, 6.5793),
    'Balestrand': (61.1975, 6.5316),
    'Flora': (61.5994, 5.0318),
    'Selje': (62.0450, 5.3490),
    'Bremanger': (61.8564, 5.2936),
    'Eid': (61.9100, 5.9864),
    'Gloppen': (61.8122, 6.2297),
    'Ørsta': (62.1994, 6.1283),
    'Ålesund': (62.4723, 6.1549),
    'Giske': (62.5031, 6.0437),
    'Rauma': (62.5667, 7.6937),
    'Tingvoll': (62.9102, 8.2109),
    'Smøla': (63.3724, 7.9925),
    'Åfjord': (63.9644, 10.2241),
    'Bjugn': (63.8190, 9.9644),
    'Hemne': (63.2921, 9.0937),
    'Rissa': (63.5816, 9.8949),
    'Meldal': (63.0476, 9.7084),
    'Rennebu': (62.8356, 9.7894),
    'Holtålen': (62.9201, 11.1407),
    'Melhus': (63.2857, 10.2764),
    'Orkdal': (63.2921, 9.8486),
    'Selbu': (63.2165, 11.0341),
    'Trondheim': (63.4305, 10.3951),
    'Stjørdal': (63.4687, 10.9223),
    'Frosta': (63.5831, 10.7607),
    'Inderøy': (63.8841, 11.2975),
    'Steinkjer': (64.0149, 11.4954),
    'Namdalseid': (64.2293, 11.2222),
    'Overhalla': (64.4946, 11.9315),
    'Hamarøy': (68.0731, 15.6345),
    'Lenvik': (69.3699, 17.9716),
    'Hamar': (60.7945, 11.0670),
    'Våler': (59.5082, 10.8735),
    'Tynset': (62.2758, 10.7712),
    'Gol': (60.7014, 8.9459),
    'Bømlo': (59.7799, 5.1831),
    'Nesset': (62.7761, 8.1345),
    'Vegårshei': (58.7666, 8.8985),
    'Vågan': (68.2804, 14.5644),
    'Harstad': (68.7983, 16.5416),
    'Skaun': (63.2519, 10.0157),
    'Steigen': (67.7836, 15.0026),
    'Vega': (65.6614, 11.9361),
    'Leikanger': (61.1866, 6.8070),
    'Eidfjord': (60.4676, 7.0675),
    'Gaular': (61.2956, 5.7432),
    'Lindås': (60.7522, 5.1649),
    'Vevelstad': (65.7550, 12.4443),
    'Dovre': (61.9849, 9.2543),
    'Bindal': (65.0483, 12.4075),
    'Porsgrunn': (59.1404, 9.6569),
    'Tydal': (63.0349, 11.6881),
    'Alstahaug': (65.9349, 12.4860),
    'Audnedal': (58.3691, 7.3683),
    'Time': (58.7254, 5.7417),
    'Høle': (58.8965, 6.0015),
    'Rendalen': (61.9369, 11.1276),
    'Meland': (60.5283, 5.2261),
    'Tysnes': (60.0447, 5.5199),
    'Nes': (60.1628, 11.4835),
    'Førde': (61.4520, 5.8579),
    'Molde': (62.7375, 7.1607),
    'Hitra': (63.6031, 8.7633),
    'Stryn': (61.9045, 6.7232),
    'Jondal': (60.2724, 6.2503),
    'Stord': (59.7806, 5.5009),
    'Agdenes': (63.5255, 9.8064),
    'Strand': (59.0236, 6.0409),
    'Sauherad': (59.4322, 9.2451),
    'Lyngdal': (58.1382, 7.0671),
    'Klæbu': (63.2896, 10.4861),
    'Mandal': (58.0274, 7.4595),
    'Tórshavnar': (62.0079, -6.7716),
    'Vága': (62.0590, -7.1326),
    'Eiðis': (62.2992, -7.0926),
    'Skúvoyar': (61.7732, -6.8131),
    'Eystur': (62.2286, -6.7091),
    'Tvøroyrar': (61.5554, -6.8139),
    'Qaasuitsup': (72.6980, -53.2423),
    'Kujalleq': (60.8302, -45.9346),
    'Sermersooq': (64.1830, -51.7216),
    'Qeqqata': (66.9167, -53.6667),
    'Kimitoön': (60.1386, 22.5150),
    'Hirvensalmi': (61.6653, 26.7695),
    'Tönning': (54.3171, 8.9366),
    'Lübeck': (53.8655, 10.6866),
    'Oldenburg': (53.1434, 8.2146),
    'Ralswiek': (54.4772, 13.4314)
}

# %%
df[['Latitude_add', 'Longtitude_add']] = df['Kommun'].map(kommun_to_latitude_longitude).apply(pd.Series)

# %%
df.drop(['Longtitute'], axis=1, inplace=True)

# %%
df.rename(columns={
    'Latitude': 'Latitude_orig', 
    'Period/Datering': 'Period'          
}, inplace=True)

# %%
df['Latitude_mix'] = df['Latitude_orig']
df['Latitude_mix'] = df['Latitude_mix'].fillna(df['Latitude_add'])


df['Longtitute_mix'] = df['Longtitute_orig']
df['Longtitute_mix'] = df['Longtitute_mix'].fillna(df['Longtitute_add'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# c:\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# c:\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'LLongtitute_orig'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
df['Plats'] = df['Plats'].fillna('')
df['Plats'] = df['Plats'].str.split(',').str[0]
df['Plats'] = df['Plats'].str.replace(',', '')
df['Plats'] = df['Plats'].str.replace('?', '')
df['Plats'] = df['Plats'].str.replace('"', '')
df['Plats'] = df['Plats'].str.split('(').str[0]
df['Plats'] = df['Plats'].str.replace('(', '')
# Out:
# C:\Users\CHARMI~1\AppData\Local\Temp/ipykernel_10380/4150665806.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['Plats'] = df['Plats'].str.replace('?', '')
# C:\Users\CHARMI~1\AppData\Local\Temp/ipykernel_10380/4150665806.py:7: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['Plats'] = df['Plats'].str.replace('(', '')

# %%
df['Socken'] = df['Socken'].fillna('')
df['Socken'] = df['Socken'].str.split('cn').str[0]

df['Socken'] = df['Socken'].str.split('?').str[0]
df['Socken'] = df['Socken'].str.replace('?', '')
# Out:
# C:\Users\CHARMI~1\AppData\Local\Temp/ipykernel_10380/1112786824.py:5: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['Socken'] = df['Socken'].str.replace('?', '')

# %%
df['Härad'] = df['Härad'].fillna('')
df['Härad'] = df['Härad'].where(~df['Härad'].str.startswith('?'), '')

# %%
df['Härad'] = df['Härad'].where(~df['Härad'].str.startswith('?'), '')
df['Härad'] = df['Härad'].str.split('hd').str[0]
df['Härad'] = df['Härad'].str.split(',').str[0]
df['Härad'] = df['Härad'].str.replace(',', '')

# %%
print(df.head())
# Out:
#      Signum             Plats         Socken        Härad      Kommun  \
# 0   Öl 1 $            Karlevi    Vickleby sn  Algutsrums   Mörbylånga
# 1  Öl 2 †$   Algutsrums kyrka  Algutsrums sn  Algutsrums   Mörbylånga
# 2  Öl 3 †$        Resmo kyrka       Resmo sn  Algutsrums   Mörbylånga
# 3   Öl 4 $        Resmo kyrka       Resmo sn  Algutsrums   Mörbylånga
# 4   Öl 5 †              Bårby  Mörbylånga sn  Algutsrums   Mörbylånga
#
#                         Placering  Koordinater Runtyper Korsform  \
# 0                             NaN  6275755.154      NaN      NaN
# 1                             NaN  6283750.154      NaN      NaN
# 2                             NaN  6268390.154      NaN      NaN
# 3  Kalmar läns museum (KLM 24962)  6268390.154      NaN      NaN
# 4                             NaN  6264000.154      NaN      NaN
#
#          Period Stilgruppering Ristare Materialtyp        Material  \
# 0     V s 900-t            RAK     NaN        sten  smålandsporfyr
# ...

# %%
output_file = r'C:\Users\charmingstar\Downloads\rundata_koordinates.csv'
df.to_csv(output_file, index=False)
